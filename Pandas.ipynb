# %% [markdown]
# <a href="https://colab.research.google.com/github/prateeksha112/coding/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/survey_results_public.csv')

# %%
df.shape
# Out:
# (16216, 79)

# %%
df.head()

# %%
pd.set_option('display.max_columns',79)
pd.set_option('display.max_rows', 79) #will display all rows

# %%
schema_df = pd.read_csv('/content/survey_results_schema.csv')

# %%
schema_df.shape
# Out:
# (79, 6)

# %%
schema_df

# %% [markdown]
# **Selecting Rows and Columns**

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df['Employment']
# Out:
# 0                                                      NaN
# 1                                      Employed, full-time
# 2                                      Employed, full-time
# 3                                      Employed, full-time
# 4                                      Employed, full-time
#                                ...
# 16211                                  Employed, full-time
# 16212               Student, part-time;Employed, part-time
# 16213                                   Student, full-time
# 16214    Employed, full-time;Independent contractor, fr...
# 16215                                   Student, full-time
# Name: Employment, Length: 16216, dtype: object

# %%
df.loc[0:3,'Employment':'LearnCodeOnline'] #will give data for rows with index 0-3(3 being inclusive) along with columns selected
# Out:
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
#iloc can alos be used for the same kind of operation but it only acceps integer values

df.iloc[[0, 1], 2] #will give row values of index 0 &1 of columns index 2
# Out:
# 0                    NaN
# 1    Employed, full-time
# Name: Employment, dtype: object

# %% [markdown]
# **Indexes - How to Set, Reset, and Use Indexes**

# %%
#schema_df

# %%
schema_df.set_index('qid', inplace=True) #this will replace index to qid(we can choose any

# %%
schema_df

# %%
schema_df.loc['QID282', 'question'] #this can be used to view qid82 corresponds to which question
# Out:
# 'Which <b>collaborative work management tools</b> did you use regularly over the past year, and which do you want to work with over the next year? Select all that apply'

# %%
#schema_df.sort_index(inplace=True) to sort the index if not soerted already

# %% [markdown]
# **Filtering - Using Conditionals to Filter Rows and Columns**

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 16211       16212  I am not primarily a developer, but I write co...
# 16212       16213  I am not primarily a developer, but I write co...
# 16213       16214                              I am learning to code
# 16214       16215  I am not primarily a developer, but I write co...
# 16215       16216                        I code primarily as a hobby
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
CompYearly = (df['ConvertedCompYearly']>70000) #we have set this condition for compyeraly

# %%
df.loc[CompYearly] #it will only give those rows for which this condition fullfills with all the columns

# %%
df.loc[CompYearly,('LearnCode','Employment','EdLevel')] #will give only for those columns which are selected in indexing

# %%
df['Country']
# Out:
# 0                                                      NaN
# 1                                                   Canada
# 2        United Kingdom of Great Britain and Northern I...
# 3                                                   Israel
# 4                                 United States of America
#                                ...
# 16211                                                India
# 16212                             United States of America
# 16213                                                India
# 16214                                               Brazil
# 16215                                          Philippines
# Name: Country, Length: 16216, dtype: object

# %%
countries =['Canada','United States of America','India','Brazil']
filt = df['Country'].isin(countries) #will give output only of these countries in the df dataset

# %%
df.loc[filt, 'Country']
# Out:
# 1                          Canada
# 4        United States of America
# 6                           India
# 7                           India
# 11       United States of America
#                    ...
# 16208                       India
# 16211                       India
# 16212    United States of America
# 16213                       India
# 16214                      Brazil
# Name: Country, Length: 5852, dtype: object

# %%
df['LanguageHaveWorkedWith'] #as we can see this ,has language names with comma therefore we cannot filter it like country
# Out:
# 0                                                    NaN
# 1                                  JavaScript;TypeScript
# 2                      C#;C++;HTML/CSS;JavaScript;Python
# 3                           C#;JavaScript;SQL;TypeScript
# 4            C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#                               ...
# 16211                                                NaN
# 16212                   Bash/Shell;C++;MATLAB;Python;SQL
# 16213                                                NaN
# 16214    Bash/Shell;C;C++;HTML/CSS;Julia;Python;Rust;VBA
# 16215                        Assembly;C++;Go;Python;Rust
# Name: LanguageHaveWorkedWith, Length: 16216, dtype: object

# %%
#suppose we want to extract those rows for which LanguageHaveWorkedWith has JavaScript in it then

#filtr = df['LanguageHaveWorkedWith'].str.contains('JavaScript')
#filtr #but this has so many NaN values therefor to tackle that we can modify the code with

# %%
filtr = df['LanguageHaveWorkedWith'].str.contains('JavaScript', na=False)
df.loc[filtr,'LanguageHaveWorkedWith'] #if we pass filtr directly it will give output as true and false
# Out:
# 1                                    JavaScript;TypeScript
# 2                        C#;C++;HTML/CSS;JavaScript;Python
# 3                             C#;JavaScript;SQL;TypeScript
# 4              C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# 6            C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
#                                ...
# 16203               Bash/Shell;HTML/CSS;JavaScript;PHP;SQL
# 16204                            C;C++;JavaScript;Python;R
# 16205    Bash/Shell;C#;Dart;HTML/CSS;Java;JavaScript;PH...
# 16206                            Bash/Shell;JavaScript;PHP
# 16208                C#;HTML/CSS;JavaScript;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 10314, dtype: object

# %% [markdown]
# **Updating Rows and Columns - Modifying Data Within DataFrames**
